# %%
import fastf1
import pandas as pd

# Enable caching for faster data loading
fastf1.Cache.enable_cache('cache')

# %%
# Import the results_df dataset
results_df = pd.read_csv('model/DATA/f1_results_2024_2025.csv')

# %%
# Load driver data from an Excel file
drivers = pd.read_excel('model/DATA/drivers_experience.xlsx')
drivers
# Out:
#    Abbreviation               FullName        TeamId  DriverExperience
# 0           NOR           Lando Norris       mclaren                51
# 1           VER         Max Verstappen      red_bull                51
# 2           RUS         George Russell      mercedes                51
# 3           ANT  Andrea Kimi Antonelli      mercedes                 1
# 4           ALB        Alexander Albon      williams                31
# 5           STR           Lance Stroll  aston_martin                49
# 6           HUL        Nico Hulkenberg        sauber                17
# 7           LEC        Charles Leclerc       ferrari                51
# 8           PIA          Oscar Piastri       mclaren                15
# 9           HAM         Lewis Hamilton       ferrari                50
# 10          GAS           Pierre Gasly        alpine                50
# 11          TSU           Yuki Tsunoda      red_bull                34
# 12          OCO           Esteban Ocon          haas                50
# 13          BEA         Oliver Bearman          haas                 2
# 14          LAW            Liam Lawson            rb                 6
# 15          BOR      Gabriel Bortoleto        sauber                 1
# 16          ALO        Fernando Alonso  aston_martin                34
# 17          SAI           Carlos Sainz      williams                51
# 18          HAD           Isack Hadjar            rb                 1
# 19          COL       Franco Colapinto        alpine                 9

# %%
filtered_results = results_df[results_df["Abbreviation"].isin(drivers['Abbreviation'])]

# Group by driver and sum total points
total_points = filtered_results.groupby("Abbreviation")["Points"].sum().reset_index()

# Fill the missing rookie drivers with 0 points
all_drivers_df = pd.DataFrame({"Abbreviation": drivers["Abbreviation"]}) 
total_points = all_drivers_df.merge(total_points, on="Abbreviation", how="left").fillna(0) 

# Convert Points to absolute value interger for simpler point system
total_points["Points"] = total_points["Points"].astype(int)
total_points = total_points.sort_values(by="Points", ascending=False)

# %%
total_points
# Out:
#    Abbreviation  Points
# 1           VER     738
# 0           NOR     711
# 8           PIA     610
# 7           LEC     536
# 2           RUS     497
# 9           HAM     338
# 17          SAI     301
# 3           ANT     125
# 16          ALO     107
# 6           HUL      85
# 4           ALB      82
# 10          GAS      60
# 5           STR      52
# 12          OCO      51
# 18          HAD      50
# 11          TSU      49
# 13          BEA      46
# 14          LAW      40
# 15          BOR      19
# 19          COL       5

# %%
drivers = total_points.merge(drivers, on="Abbreviation", how="left").fillna(0) 
drivers
# Out:
#    Abbreviation  Points               FullName        TeamId  DriverExperience
# 0           VER     738         Max Verstappen      red_bull                51
# 1           NOR     711           Lando Norris       mclaren                51
# 2           PIA     610          Oscar Piastri       mclaren                15
# 3           LEC     536        Charles Leclerc       ferrari                51
# 4           RUS     497         George Russell      mercedes                51
# 5           HAM     338         Lewis Hamilton       ferrari                50
# 6           SAI     301           Carlos Sainz      williams                51
# 7           ANT     125  Andrea Kimi Antonelli      mercedes                 1
# 8           ALO     107        Fernando Alonso  aston_martin                34
# 9           HUL      85        Nico Hulkenberg        sauber                17
# 10          ALB      82        Alexander Albon      williams                31
# 11          GAS      60           Pierre Gasly        alpine                50
# 12          STR      52           Lance Stroll  aston_martin                49
# 13          OCO      51           Esteban Ocon          haas                50
# 14          HAD      50           Isack Hadjar            rb                 1
# 15          TSU      49           Yuki Tsunoda      red_bull                34
# 16          BEA      46         Oliver Bearman          haas                 2
# 17          LAW      40            Liam Lawson            rb                 6
# 18          BOR      19      Gabriel Bortoleto        sauber                 1
# 19          COL       5       Franco Colapinto        alpine                 9

# %%
# Calculate average qualifying position for each driver
avg_quali_df = results_df.groupby('Abbreviation')['GridPosition'].mean().reset_index()
avg_quali_df.rename(columns={'GridPosition': 'AvgQualiPosition'}, inplace=True)

# %%
# Calculate average race position for each driver
avg_race_df = results_df.groupby('Abbreviation')['Position'].mean().reset_index()
avg_race_df.rename(columns={'Position': 'AvgRacePosition'}, inplace=True)

# %%
# Merge both dataframes
avg_pos_df = avg_quali_df.merge(avg_race_df, on='Abbreviation', how='outer')

# Merge the drivers DataFrame with avg_pos_df to include AvgQualiPosition and AvgRacePosition
drivers = drivers.merge(avg_pos_df, on='Abbreviation', how='left')

# Display updated drivers dataset
drivers
# Out:
#    Abbreviation  Points               FullName        TeamId  \
# 0           VER     738         Max Verstappen      red_bull
# 1           NOR     711           Lando Norris       mclaren
# 2           PIA     610          Oscar Piastri       mclaren
# 3           LEC     536        Charles Leclerc       ferrari
# 4           RUS     497         George Russell      mercedes
# 5           HAM     338         Lewis Hamilton       ferrari
# 6           SAI     301           Carlos Sainz      williams
# 7           ANT     125  Andrea Kimi Antonelli      mercedes
# 8           ALO     107        Fernando Alonso  aston_martin
# 9           HUL      85        Nico Hulkenberg        sauber
# 10          ALB      82        Alexander Albon      williams
# 11          GAS      60           Pierre Gasly        alpine
# 12          STR      52           Lance Stroll  aston_martin
# 13          OCO      51           Esteban Ocon          haas
# 14          HAD      50           Isack Hadjar            rb
# 15          TSU      49           Yuki Tsunoda      red_bull
# 16          BEA      46         Oliver Bearman          haas
# 17          LAW      40            Liam Lawson            rb
# 18          BOR      19      Gabriel Bortoleto        sauber
# 19          COL       5       Franco Colapinto        alpine
#
#     DriverExperience  AvgQualiPosition  AvgRacePosition
# 0                 51          3.630435         3.760870
# 1                 51          3.217391         4.304348
# 2                 15          4.304348         4.782609
# 3                 51          5.326087         5.630435
# 4                 51          5.043478         5.652174
# 5                 50          8.782609         7.630435
# 6                 51          8.444444         9.044444
# 7                  1          8.681818         9.818182
# 8                 34          9.934783        11.217391
# 9                 17         13.239130        12.108696
# 10                31         12.695652        12.760870
# 11                50         13.217391        13.565217
# 12                49         14.022222        13.533333
# 13                50         14.333333        13.177778
# 14                 1         10.000000        11.272727
# 15                34         11.891304        12.913043
# 16                 2         14.120000        11.240000
# 17                 6         12.500000        12.892857
# 18                 1         14.318182        14.454545
# 19                 9         16.000000        15.080000

# %%
# Remove the 'Drivers'sExperince ' column from the drivers DataFrame as it's not needed
filtered_drivers_info = drivers.drop(['DriverExperience'], axis=1)
filtered_drivers_info
# Out:
#    Abbreviation  Points               FullName        TeamId  \
# 0           VER     738         Max Verstappen      red_bull
# 1           NOR     711           Lando Norris       mclaren
# 2           PIA     610          Oscar Piastri       mclaren
# 3           LEC     536        Charles Leclerc       ferrari
# 4           RUS     497         George Russell      mercedes
# 5           HAM     338         Lewis Hamilton       ferrari
# 6           SAI     301           Carlos Sainz      williams
# 7           ANT     125  Andrea Kimi Antonelli      mercedes
# 8           ALO     107        Fernando Alonso  aston_martin
# 9           HUL      85        Nico Hulkenberg        sauber
# 10          ALB      82        Alexander Albon      williams
# 11          GAS      60           Pierre Gasly        alpine
# 12          STR      52           Lance Stroll  aston_martin
# 13          OCO      51           Esteban Ocon          haas
# 14          HAD      50           Isack Hadjar            rb
# 15          TSU      49           Yuki Tsunoda      red_bull
# 16          BEA      46         Oliver Bearman          haas
# 17          LAW      40            Liam Lawson            rb
# 18          BOR      19      Gabriel Bortoleto        sauber
# 19          COL       5       Franco Colapinto        alpine
#
#     AvgQualiPosition  AvgRacePosition
# 0           3.630435         3.760870
# 1           3.217391         4.304348
# 2           4.304348         4.782609
# 3           5.326087         5.630435
# 4           5.043478         5.652174
# 5           8.782609         7.630435
# 6           8.444444         9.044444
# 7           8.681818         9.818182
# 8           9.934783        11.217391
# 9          13.239130        12.108696
# 10         12.695652        12.760870
# 11         13.217391        13.565217
# 12         14.022222        13.533333
# 13         14.333333        13.177778
# 14         10.000000        11.272727
# 15         11.891304        12.913043
# 16         14.120000        11.240000
# 17         12.500000        12.892857
# 18         14.318182        14.454545
# 19         16.000000        15.080000

# %%
filtered_drivers_info.to_csv('model/DATA/filtered_drivers_info.csv')

# %%
# Select only relevant features from results_df for further processing
filtered_results_df = results_df[['Round', 'Abbreviation', 'GridPosition', 'Position']]
filtered_results_df
# Out:
#      Round Abbreviation  GridPosition  Position
# 0        1          VER           1.0       1.0
# 1        1          SAI           4.0       3.0
# 2        1          LEC           2.0       4.0
# 3        1          RUS           3.0       5.0
# 4        1          NOR           7.0       6.0
# ..     ...          ...           ...       ...
# 787     22          ALB          16.0      16.0
# 788     22          BOR          18.0      17.0
# 789     22          STR          12.0      18.0
# 790     22          NOR           1.0      19.0
# 791     22          PIA           5.0      20.0
#
# [792 rows x 4 columns]

# %%
# Merge the filtered race results with driver information using 'Abbreviation' as the key
# This combines race performance with driver statistics and gives the final dataset to use for prediction
final_df = filtered_results_df.merge(filtered_drivers_info, on='Abbreviation', how='left')
final_df
# Out:
#      Round Abbreviation  GridPosition  Position  Points           FullName  \
# 0        1          VER           1.0       1.0   738.0     Max Verstappen
# 1        1          SAI           4.0       3.0   301.0       Carlos Sainz
# 2        1          LEC           2.0       4.0   536.0    Charles Leclerc
# 3        1          RUS           3.0       5.0   497.0     George Russell
# 4        1          NOR           7.0       6.0   711.0       Lando Norris
# ..     ...          ...           ...       ...     ...                ...
# 787     22          ALB          16.0      16.0    82.0    Alexander Albon
# 788     22          BOR          18.0      17.0    19.0  Gabriel Bortoleto
# 789     22          STR          12.0      18.0    52.0       Lance Stroll
# 790     22          NOR           1.0      19.0   711.0       Lando Norris
# 791     22          PIA           5.0      20.0   610.0      Oscar Piastri
#
#            TeamId  AvgQualiPosition  AvgRacePosition
# 0        red_bull          3.630435         3.760870
# 1        williams          8.444444         9.044444
# 2         ferrari          5.326087         5.630435
# 3        mercedes          5.043478         5.652174
# 4         mclaren          3.217391         4.304348
# ..            ...               ...              ...
# 787      williams         12.695652        12.760870
# 788        sauber         14.318182        14.454545
# 789  aston_martin         14.022222        13.533333
# 790       mclaren          3.217391         4.304348
# 791       mclaren          4.304348         4.782609
#
# [792 rows x 9 columns]

# %%
final_df["QualifyingScore"] = (final_df["AvgQualiPosition"] + final_df["GridPosition"]) / 2
final_df
# Out:
#      Round Abbreviation  GridPosition  Position  Points           FullName  \
# 0        1          VER           1.0       1.0   738.0     Max Verstappen
# 1        1          SAI           4.0       3.0   301.0       Carlos Sainz
# 2        1          LEC           2.0       4.0   536.0    Charles Leclerc
# 3        1          RUS           3.0       5.0   497.0     George Russell
# 4        1          NOR           7.0       6.0   711.0       Lando Norris
# ..     ...          ...           ...       ...     ...                ...
# 787     22          ALB          16.0      16.0    82.0    Alexander Albon
# 788     22          BOR          18.0      17.0    19.0  Gabriel Bortoleto
# 789     22          STR          12.0      18.0    52.0       Lance Stroll
# 790     22          NOR           1.0      19.0   711.0       Lando Norris
# 791     22          PIA           5.0      20.0   610.0      Oscar Piastri
#
#            TeamId  AvgQualiPosition  AvgRacePosition  QualifyingScore
# 0        red_bull          3.630435         3.760870         2.315217
# 1        williams          8.444444         9.044444         6.222222
# 2         ferrari          5.326087         5.630435         3.663043
# 3        mercedes          5.043478         5.652174         4.021739
# 4         mclaren          3.217391         4.304348         5.108696
# ..            ...               ...              ...              ...
# 787      williams         12.695652        12.760870        14.347826
# 788        sauber         14.318182        14.454545        16.159091
# 789  aston_martin         14.022222        13.533333        13.011111
# 790       mclaren          3.217391         4.304348         2.108696
# 791       mclaren          4.304348         4.782609         4.652174
#
# [792 rows x 10 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Round             792 non-null    int64
#  1   Abbreviation      792 non-null    object
#  2   GridPosition      792 non-null    float64
#  3   Position          792 non-null    float64
#  4   Points            785 non-null    float64
#  5   FullName          785 non-null    object
#  6   TeamId            785 non-null    object
#  7   AvgQualiPosition  785 non-null    float64
#  8   AvgRacePosition   785 non-null    float64
#  9   QualifyingScore   785 non-null    float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 62.0+ KB

# %%
# Count and find if there are any null values in the dataset
final_df.isnull().sum()
# Out:
# Round               0
# Abbreviation        0
# GridPosition        0
# Position            0
# Points              7
# FullName            7
# TeamId              7
# AvgQualiPosition    7
# AvgRacePosition     7
# QualifyingScore     7
# dtype: int64

# %%
df_clean = final_df.dropna()

# %%
df_clean.isnull().sum()
# Out:
# Round               0
# Abbreviation        0
# GridPosition        0
# Position            0
# Points              0
# FullName            0
# TeamId              0
# AvgQualiPosition    0
# AvgRacePosition     0
# QualifyingScore     0
# dtype: int64

# %%
df_clean.to_csv('model/DATA/f1_final_data.csv', index=False)
